# %%
from numpy import random
x = random.randint(100)
print(x)
# Out:
# 32

# %%
from numpy import random
x = random.rand(100)
print(x)
# Out:
# [0.07866074 0.714771   0.12430591 0.04243148 0.22022722 0.35141929
#  0.58295643 0.47364255 0.88225656 0.0953363  0.64248389 0.85333752
#  0.76573826 0.90476806 0.37214191 0.05597126 0.48424495 0.65414085
#  0.38594374 0.79150255 0.81334629 0.70183406 0.20591834 0.51651015
#  0.44377373 0.06710012 0.87082434 0.47983699 0.36386942 0.87419305
#  0.47402319 0.22830709 0.39827962 0.85468743 0.93029437 0.47184519
#  0.38441677 0.51756864 0.6951474  0.00306379 0.58585191 0.94026082
#  0.05616895 0.12401489 0.20419146 0.15744213 0.51731215 0.07223523
#  0.1115093  0.16825319 0.09861484 0.86233764 0.46795982 0.40963176
#  0.88994157 0.74473774 0.4011846  0.2280812  0.99498203 0.25711426
#  0.93097913 0.80012922 0.02850413 0.28990245 0.54281458 0.89430274
#  0.10732117 0.53095912 0.04239865 0.61419482 0.48908479 0.52001665
#  0.26727981 0.07837    0.58973559 0.52170438 0.31613193 0.0140929
#  0.82248702 0.38134425 0.1995612  0.12984252 0.44493727 0.23001331
#  0.91119662 0.09228796 0.64358737 0.38939042 0.42639596 0.8132447
#  0.8073741  0.75453606 0.55191558 0.97651791 0.26793796 0.63778785
#  0.30778654 0.24014885 0.54315135 0.58719502]

# %%
from numpy import random
x = random.choice([2,4,6,8],p=[0.1,0.3,0.6,0.0],size=(100))
print(x)
# Out:
# [6 6 6 6 6 4 6 4 6 6 4 6 6 6 6 6 6 4 4 4 6 4 6 4 2 6 2 2 6 4 2 4 6 6 2 4 6
#  6 4 6 6 6 4 6 6 6 6 6 4 4 6 6 6 4 6 6 6 4 6 6 4 6 6 4 2 6 6 6 6 4 6 2 6 6
#  6 4 4 6 6 6 6 6 4 4 4 6 6 6 4 6 6 6 2 6 2 4 4 6 6 6]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns 
sns.distplot(random.normal(size=666), hist=True)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_37768\3228719206.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=666), hist=True)

# %%
from numpy import random
x = random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [3 6 7 5 6 8 7 4 4 5]

# %%
from numpy import random
x = random.exp(n=10,p=0.5,size=10)
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 2
#       1 from numpy import random
# ----> 2 x = random.exp(n=10,p=0.5,size=10)
#       3 print(x)
#
# AttributeError: module 'numpy.random' has no attribute 'exp'
